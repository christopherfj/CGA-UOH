# %% [markdown]
# #Repaso básico de python

# %%
#Nombre de variables
var = 10
var2 = 20
var_3 = 30
#1var = 50 #error
4%2
# Out:
# 0

# %%
#Variable entera
v = 10
v
# Out:
# 10

# %%
#Variable decimal
v = 10.5
v

# %%
#Variable string
v = "hola"
v
# Out:
# 'hola'

# %%
#Variable booleana
b = False
b
# Out:
# False

# %%
#Lista
lista = [22,2,2] #list()
lista.append(2)
lista.append(-1)
#lista.count(-2)
print( lista[0:2] )
# Out:
# [22, 2]

# %%
#Diccionario
d = {'uoh':[10,-1], 1:2, 2:2} #dict()
#d['uoh']
d.values()
# Out:
# dict_values([[10, -1], 2, 2])

# %%
#Salida (print)
print("Hola mundo")
# Out:
# Hola mundo

# %%
#Entrada/salida (input/print)
nombre = input("Ingresa nombre: ")
anho = int( input("Ingrese año: ") )
print("Hola ", nombre, anho)
# Out:
# Ingresa nombre: Christopher
# Ingrese año: 2023
# Hola  Christopher 2023

# %%
#Concatenacion de strings
string1 = "Hola"
string2 = " mundo"
print(string1+string2)
# Out:
# Hola mundo

# %% [markdown]
# #Ejercicios

# %%
#P1
print("Hola mundo")
print("Hola"+' mundo')
# Out:
# Hola mundo
# Hola mundo

# %% [markdown]
# ![P1.png](data:image/png;base64,...)

# %%
#P2
r = float( input("radio: ") )
pi = 3.14
#area = pi*r*r
area = pi*(r**2)
area = pi*pow(r,2)
print(area)
# Out:
# radio: 2
# 12.56

# %% [markdown]
# ![P2.png](data:image/png;base64,...)

# %%
#P3
n1 = int( input('n1: ') )
n2 = int( input('n2: ') )
if n1>n2:
    print(n1, 'mayor que', n2)
else:
    print(n2, 'mayor que', n1)
# Out:
# n1: 1
# n2: 10
# 10 mayor que 1

# %% [markdown]
# ![P3.png](data:image/png;base64,...)

# %%
#P4
numero = float(input("Ingrese un numero: "))
while( numero <= 0):
    print("Vuelva a introducir el numero")
    numero = float(input("Ingrese un numero: "))
print(numero)
# Out:
# Ingrese un numero: -1
# Vuelva a introducir el numero
# Ingrese un numero: -10
# Vuelva a introducir el numero
# Ingrese un numero: 0
# Vuelva a introducir el numero
# Ingrese un numero: 10
# 10.0

# %% [markdown]
# ![P4.png](data:image/png;base64,...)

# %%
#bonus
lista = [1,2,3,4]
n = len(lista)
s = 0

for uoh in lista:
    if (uoh%2)==0:
        s = s+uoh
        #s +=uoh
print(s)

#for i in range(0,n):
#    print(i, '->', lista[i])
# Out:
# 6

# %% [markdown]
# ![bonus.png](data:image/png;base64,...)
